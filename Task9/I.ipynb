# %% [markdown]
# [![Open Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/123SVymuhF1BESHzoaDEZu0kI4rhQLO1k?usp=sharing)

# %%
import zipfile
import os

# Path to the uploaded zip file
zip_file_path = '/content/I.zip'

# Directory to extract the contents of the zip file
extracted_folder_path = '/content/I/'

# Extracting the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# Listing the extracted files
extracted_files = os.listdir(extracted_folder_path)
extracted_files.sort()
extracted_files
# Out:
# ['Animals']

# %%
# Path to the extracted "Animals" folder
animals_folder_path = os.path.join(extracted_folder_path, 'Animals')

# Listing the files in the "Animals" folder
animals_files = os.listdir(animals_folder_path)
animals_files.sort()
animals_files
# Out:
# ['bird', 'cat', 'dog']

# %%
# Paths to the subfolders within the "Animals" folder
bird_folder_path = os.path.join(animals_folder_path, 'bird')
cat_folder_path = os.path.join(animals_folder_path, 'cat')
dog_folder_path = os.path.join(animals_folder_path, 'dog')

# Listing the files in each subfolder
bird_files = os.listdir(bird_folder_path)
cat_files = os.listdir(cat_folder_path)
dog_files = os.listdir(dog_folder_path)

bird_files.sort()
cat_files.sort()
dog_files.sort()

(bird_files, cat_files, dog_files)
# Out:
# (['00b01445_nohash_0.wav',
#   '00f0204f_nohash_1.wav',
#   '00f0204f_nohash_3.wav',
#   '01648c51_nohash_0.wav',
#   '01bcfc0c_nohash_1.wav',
#   '0474c92a_nohash_0.wav',
#   '095847e4_nohash_0.wav',
#   '096456f9_nohash_0.wav',
#   '09bcdc9d_nohash_0.wav',
#   '0a7c2a8d_nohash_0.wav',
#   '0b40aa8e_nohash_0.wav',
#   '0b56bcfe_nohash_0.wav',
#   '0bde966a_nohash_0.wav',
#   '0f7dc557_nohash_0.wav',
#   '12c206ea_nohash_0.wav',
#   '13199b79_nohash_1.wav',
#   '1942abd7_nohash_0.wav',
#   '1a6eca98_nohash_0.wav',
#   '1b4c9b89_nohash_0.wav',
#   '1bc45db9_nohash_0.wav',
#   '1bc45db9_nohash_1.wav',
#   '1d1fe0a0_nohash_0.wav',
#   '1ed557b9_nohash_0.wav',
#   '1f3bece8_nohash_0.wav',
#   '214ccb20_nohash_0.wav',
#   '214ccb20_nohash_1.wav',
#   '215699ff_nohash_1.wav',
#   '2296b1af_nohash_1.wav',
#   '24c9f572_nohash_1.wav',
#   '257e17e0_nohash_0.wav',
#   '270bfa52_nohash_0.wav',
#   '27b03931_nohash_0.wav',
#   '28ed6bc9_nohash_0.wav',
#   '29fb33da_nohash_0.wav',
#   '2b42e7a2_nohash_0.wav',
#   '2c7c33e8_nohash_0.wav',
#   '30a09789_nohash_1.wav',
#   '31267b59_nohash_0.wav',
#   '31270cb2_nohash_0.wav',
#   '34881b10_nohash_0.wav',
#   '3565ca83_nohash_0.wav',
#   '39dce8cc_nohash_0.wav',
#   '3c8836dc_nohash_0.wav',
#   '3ca784ec_nohash_0.wav',
#   '3e31dffe_nohash_0.wav',
#   '402e2977_nohash_1.wav',
#   '422d3197_nohash_0.wav',
#   '43691f67_nohash_1.wav',
#   '43691f67_nohash_4.wav',
#   '44715c1c_nohash_0.wav',
#   '44dad20e_nohash_0.wav',
#   '44fb4274_nohash_0.wav',
#   '48a8a69d_nohash_2.wav',
#   '4954abe8_nohash_2.wav',
#   '4c13fe25_nohash_1.wav',
#   '4cb874bb_nohash_2.wav',
#   '4f5c0b28_nohash_0.wav',
#   '4f5c0b28_nohash_1.wav',
#   '4f781a59_nohash_1.wav',
#   '50d1c8e3_nohash_1.wav',
#   '520b2c17_nohash_0.wav',
#   '529eda42_nohash_1.wav',
#   '531a5b8a_nohash_0.wav',
#   '540d8427_nohash_0.wav',
#   '541e4079_nohash_1.wav',
#   '56f78b7e_nohash_0.wav',
#   '5744b6a7_nohash_0.wav',
#   '5828dfa2_nohash_0.wav',
#   '59c3a7f2_nohash_2.wav',
#   '5c39594f_nohash_0.wav',
#   '5f8e50a0_nohash_0.wav',
#   '61a9f72a_nohash_0.wav',
#   '626e323f_nohash_1.wav',
#   '6272b231_nohash_0.wav',
#   '638548d5_nohash_2.wav',
#   '64da5281_nohash_0.wav',
#   '64da5281_nohash_1.wav',
#   '650daf8e_nohash_0.wav',
#   '650daf8e_nohash_1.wav',
#   '659b7fae_nohash_2.wav',
#   '65d81c54_nohash_0.wav',
#   '6a014b29_nohash_1.wav',
#   '6a27a9bf_nohash_0.wav',
#   '6b889021_nohash_1.wav',
#   '6cb6eee7_nohash_0.wav',
#   '6cf5459b_nohash_0.wav',
#   '6e2ef3d5_nohash_1.wav',
#   '72aa7259_nohash_0.wav',
#   '73cccfaf_nohash_1.wav',
#   '73f0c1f7_nohash_0.wav',
#   '743edf9d_nohash_0.wav',
#   '750e3e75_nohash_0.wav',
#   '7799c9cd_nohash_0.wav',
#   '78102205_nohash_0.wav',
#   '78622c2b_nohash_0.wav',
#   '7910d292_nohash_0.wav',
#   '7add4c5f_nohash_0.wav',
#   '7b2e879e_nohash_0.wav',
#   '7bae88ed_nohash_0.wav',
#   '7bae88ed_nohash_1.wav',
#   '7c75a504_nohash_0.wav',
#   '7cfb1618_nohash_1.wav',
#   '7e1054e7_nohash_2.wav',
#   '7e783e3f_nohash_0.wav',
#   '7f74626f_nohash_0.wav',
#   '8281a2a8_nohash_0.wav',
#   '84bf12ff_nohash_0.wav',
#   '8549f25d_nohash_0.wav',
#   '876c84d6_nohash_0.wav',
#   '881583a6_nohash_0.wav',
#   '8a28231e_nohash_0.wav',
#   '8f3f252c_nohash_0.wav',
#   '91cdef62_nohash_1.wav',
#   '92a9c5e6_nohash_0.wav',
#   '92b2bf59_nohash_0.wav',
#   '96c66ab7_nohash_0.wav',
#   '97f493b9_nohash_0.wav',
#   '988e2f9a_nohash_1.wav',
#   '9d32f10a_nohash_0.wav',
#   '9e2ce5e3_nohash_0.wav',
#   '9f6fbdb4_nohash_0.wav',
#   '9f869f70_nohash_1.wav',
#   'a0f93943_nohash_1.wav',
#   'a4b21cbc_nohash_1.wav',
#   'a5d485dc_nohash_0.wav',
#   'a5d485dc_nohash_2.wav',
#   'a60a09cf_nohash_0.wav',
#   'a84dee7b_nohash_0.wav',
#   'a8cf01bc_nohash_0.wav',
#   'aa109cfb_nohash_0.wav',
#   'aa233654_nohash_0.wav',
#   'ab76ac76_nohash_0.wav',
#   'ab76ac76_nohash_1.wav',
#   'ae04cdbe_nohash_0.wav',
#   'ae927455_nohash_0.wav',
#   'af7a8296_nohash_0.wav',
#   'b17f5ba0_nohash_1.wav',
#   'b43c8f2f_nohash_0.wav',
#   'b6091c84_nohash_0.wav',
#   'b71ebf79_nohash_1.wav',
#   'b7a0754f_nohash_0.wav',
#   'b97c9f77_nohash_0.wav',
#   'b9db6e42_nohash_0.wav',
#   'be7a5b2d_nohash_0.wav',
#   'bf70feda_nohash_0.wav',
#   'c0445658_nohash_0.wav',
#   'c103a2d5_nohash_1.wav',
#   'c2d15ea5_nohash_0.wav',
#   'c53b335a_nohash_0.wav',
#   'c661be6e_nohash_0.wav',
#   'c948d727_nohash_0.wav',
#   'caf1803e_nohash_0.wav',
#   'ccb1266b_nohash_0.wav',
#   'cce17a61_nohash_1.wav',
#   'cd85758f_nohash_0.wav',
#   'cdbd6969_nohash_1.wav',
#   'ceaadb24_nohash_0.wav',
#   'd069e6ff_nohash_1.wav',
#   'd4082f3e_nohash_0.wav',
#   'd53e25ba_nohash_0.wav',
#   'd8521ea0_nohash_0.wav',
#   'd8c52371_nohash_1.wav',
#   'd9b50b8b_nohash_2.wav',
#   'd9d6559e_nohash_0.wav',
#   'da7689f1_nohash_0.wav',
#   'dce5041a_nohash_0.wav',
#   'de08912f_nohash_0.wav',
#   'e0322f2c_nohash_0.wav',
#   'e04d7130_nohash_0.wav',
#   'e2008f39_nohash_0.wav',
#   'e32ff49d_nohash_0.wav',
#   'e55a2b20_nohash_0.wav',
#   'e5dadd24_nohash_0.wav',
#   'e652590d_nohash_1.wav',
#   'e6e29c47_nohash_0.wav',
#   'e71b4ce6_nohash_0.wav',
#   'e77d88fc_nohash_1.wav',
#   'ead2934a_nohash_0.wav',
#   'ed3c2d05_nohash_0.wav',
#   'edd8bfe3_nohash_0.wav',
#   'ee4a907f_nohash_0.wav',
#   'f0edc767_nohash_2.wav',
#   'f1d36c53_nohash_0.wav',
#   'f42e234b_nohash_0.wav',
#   'f5733968_nohash_0.wav',
#   'f6581345_nohash_1.wav',
#   'f6617a86_nohash_0.wav',
#   'f6af2457_nohash_0.wav',
#   'f804cbb3_nohash_0.wav',
#   'f839238a_nohash_1.wav',
#   'f88f97a7_nohash_0.wav',
#   'ffa76c4a_nohash_0.wav',
#   'ffb86d3c_nohash_0.wav'],
#  ['00f0204f_nohash_2.wav',
#   '03cf93b1_nohash_0.wav',
#   '095847e4_nohash_0.wav',
#   '096456f9_nohash_0.wav',
#   '0e5193e6_nohash_0.wav',
#   '0f7dc557_nohash_0.wav',
#   '10c6d873_nohash_1.wav',
#   '11860c84_nohash_0.wav',
#   '13199b79_nohash_1.wav',
#   '1657c9fa_nohash_0.wav',
#   '16db1582_nohash_1.wav',
#   '171b56dc_nohash_0.wav',
#   '172dc2b0_nohash_0.wav',
#   '179a61b7_nohash_0.wav',
#   '187af8be_nohash_0.wav',
#   '1a9afd33_nohash_0.wav',
#   '1bc45db9_nohash_0.wav',
#   '1bc45db9_nohash_1.wav',
#   '1dce06e8_nohash_1.wav',
#   '1e9b215e_nohash_1.wav',
#   '1f3bece8_nohash_0.wav',
#   '1ffd513b_nohash_1.wav',
#   '22aa3665_nohash_0.wav',
#   '25132942_nohash_0.wav',
#   '2903efb3_nohash_0.wav',
#   '29fb33da_nohash_0.wav',
#   '2a0b413e_nohash_0.wav',
#   '2a89ad5c_nohash_0.wav',
#   '2aa787cf_nohash_2.wav',
#   '2ad772d6_nohash_1.wav',
#   '2da58b32_nohash_0.wav',
#   '32561e9e_nohash_0.wav',
#   '325a0c39_nohash_1.wav',
#   '33b5516a_nohash_0.wav',
#   '34805883_nohash_1.wav',
#   '35c8fa78_nohash_1.wav',
#   '364f979f_nohash_0.wav',
#   '380abbad_nohash_0.wav',
#   '38c30a4a_nohash_0.wav',
#   '39a6b995_nohash_0.wav',
#   '3a182c98_nohash_0.wav',
#   '3ac2e76f_nohash_0.wav',
#   '3bc21161_nohash_0.wav',
#   '3cbd76a3_nohash_0.wav',
#   '409c962a_nohash_0.wav',
#   '4249c833_nohash_1.wav',
#   '4422e51d_nohash_1.wav',
#   '4620dc14_nohash_0.wav',
#   '471a0925_nohash_0.wav',
#   '479e64cc_nohash_0.wav',
#   '48e8b82a_nohash_0.wav',
#   '4abefdf5_nohash_0.wav',
#   '4bb1244f_nohash_0.wav',
#   '4c4d2526_nohash_1.wav',
#   '4ca37738_nohash_0.wav',
#   '4fd4d073_nohash_0.wav',
#   '518588b6_nohash_0.wav',
#   '53458368_nohash_0.wav',
#   '571c044e_nohash_0.wav',
#   '57b68383_nohash_0.wav',
#   '5a3712c9_nohash_2.wav',
#   '5aac2efa_nohash_0.wav',
#   '5c8af87a_nohash_0.wav',
#   '5d0ab165_nohash_0.wav',
#   '5e3b7a84_nohash_1.wav',
#   '6205088b_nohash_0.wav',
#   '62ef962d_nohash_0.wav',
#   '64f83f0e_nohash_0.wav',
#   '650daf8e_nohash_1.wav',
#   '65d14087_nohash_0.wav',
#   '66774579_nohash_0.wav',
#   '66aa0f29_nohash_0.wav',
#   '66cff190_nohash_0.wav',
#   '6794a793_nohash_0.wav',
#   '682e1687_nohash_0.wav',
#   '69f609ec_nohash_0.wav',
#   '6c2dd2d5_nohash_0.wav',
#   '6cf5459b_nohash_1.wav',
#   '72aa7259_nohash_0.wav',
#   '73f0c1f7_nohash_0.wav',
#   '73f0c1f7_nohash_1.wav',
#   '747e69fd_nohash_1.wav',
#   '748cb308_nohash_0.wav',
#   '78102205_nohash_0.wav',
#   '784e281a_nohash_0.wav',
#   '7c75a504_nohash_0.wav',
#   '7c9b43f0_nohash_1.wav',
#   '7f17667c_nohash_3.wav',
#   '7fa5fa1f_nohash_0.wav',
#   '7ff4fc72_nohash_1.wav',
#   '81a345a3_nohash_0.wav',
#   '8335f893_nohash_0.wav',
#   '83957201_nohash_1.wav',
#   '83f9c4ab_nohash_0.wav',
#   '84bf12ff_nohash_0.wav',
#   '850e2222_nohash_0.wav',
#   '863880b7_nohash_1.wav',
#   '86cb59b2_nohash_0.wav',
#   '87014d40_nohash_2.wav',
#   '888a0c49_nohash_0.wav',
#   '89865a6f_nohash_1.wav',
#   '89ed36ab_nohash_0.wav',
#   '89f680f3_nohash_0.wav',
#   '8bbd98d0_nohash_0.wav',
#   '8c7c9168_nohash_2.wav',
#   '90b94017_nohash_0.wav',
#   '93f30cc4_nohash_0.wav',
#   '95218ce8_nohash_0.wav',
#   '953fe1ad_nohash_0.wav',
#   '95ba4996_nohash_1.wav',
#   '96c66ab7_nohash_2.wav',
#   '97e0c576_nohash_1.wav',
#   '981e2a16_nohash_0.wav',
#   '99081f4d_nohash_1.wav',
#   '99a9b015_nohash_0.wav',
#   '9c06a3f3_nohash_0.wav',
#   '9d171fee_nohash_0.wav',
#   '9f6fbdb4_nohash_0.wav',
#   '9f6fbdb4_nohash_1.wav',
#   '9f7079fe_nohash_1.wav',
#   '9f869f70_nohash_1.wav',
#   'a13e0a74_nohash_0.wav',
#   'a1dd919f_nohash_0.wav',
#   'a3502f15_nohash_0.wav',
#   'a4b21cbc_nohash_1.wav',
#   'a4e8a997_nohash_0.wav',
#   'a5609cce_nohash_1.wav',
#   'a8cf01bc_nohash_1.wav',
#   'a902ce9b_nohash_0.wav',
#   'a996cf66_nohash_0.wav',
#   'ab5ae445_nohash_1.wav',
#   'ad1429cf_nohash_0.wav',
#   'ae04cdbe_nohash_0.wav',
#   'af130f12_nohash_1.wav',
#   'af7a8296_nohash_0.wav',
#   'afe0b87d_nohash_0.wav',
#   'b00dff7e_nohash_1.wav',
#   'b12bef84_nohash_0.wav',
#   'b21f0fa4_nohash_1.wav',
#   'b2fbe484_nohash_1.wav',
#   'b36c27c2_nohash_0.wav',
#   'b3bdded5_nohash_0.wav',
#   'b59fe16d_nohash_1.wav',
#   'b7a0754f_nohash_0.wav',
#   'b8872c20_nohash_0.wav',
#   'b93528e3_nohash_0.wav',
#   'ba676390_nohash_1.wav',
#   'bbd0bbd0_nohash_0.wav',
#   'bc065a17_nohash_0.wav',
#   'bca56796_nohash_0.wav',
#   'bcdaa7a9_nohash_2.wav',
#   'be7a5b2d_nohash_0.wav',
#   'bf4af1af_nohash_0.wav',
#   'bfa63751_nohash_0.wav',
#   'bfdb9801_nohash_0.wav',
#   'c08e5058_nohash_2.wav',
#   'c103a2d5_nohash_2.wav',
#   'c120e80e_nohash_0.wav',
#   'c120e80e_nohash_1.wav',
#   'c53b335a_nohash_0.wav',
#   'cb802c63_nohash_0.wav',
#   'cc3d1613_nohash_3.wav',
#   'cd85758f_nohash_0.wav',
#   'ce49cb60_nohash_0.wav',
#   'ce9410da_nohash_0.wav',
#   'd0426d63_nohash_0.wav',
#   'd0faf7e4_nohash_0.wav',
#   'd57febf0_nohash_2.wav',
#   'd5c41d6a_nohash_0.wav',
#   'd6360b32_nohash_1.wav',
#   'd71ad617_nohash_0.wav',
#   'd933bf5e_nohash_2.wav',
#   'd9ae8983_nohash_0.wav',
#   'da2c5f1b_nohash_0.wav',
#   'dabd70c2_nohash_0.wav',
#   'db9d52d2_nohash_0.wav',
#   'dc2222d7_nohash_1.wav',
#   'dce5041a_nohash_0.wav',
#   'dd086776_nohash_0.wav',
#   'e14d3db8_nohash_0.wav',
#   'e3e49931_nohash_0.wav',
#   'e53139ad_nohash_0.wav',
#   'e57abea3_nohash_1.wav',
#   'e5e54cee_nohash_0.wav',
#   'e7117d00_nohash_0.wav',
#   'e71b4ce6_nohash_1.wav',
#   'e9287461_nohash_1.wav',
#   'ead2934a_nohash_1.wav',
#   'eb67fcbc_nohash_0.wav',
#   'ed3c2d05_nohash_0.wav',
#   'ee4a907f_nohash_1.wav',
#   'efbc3952_nohash_0.wav',
#   'f17be97f_nohash_0.wav',
#   'f216055e_nohash_1.wav',
#   'f264e0df_nohash_0.wav',
#   'f2a90886_nohash_0.wav',
#   'f4386675_nohash_1.wav',
#   'f5733968_nohash_0.wav',
#   'f632210f_nohash_1.wav',
#   'f6617a86_nohash_0.wav',
#   'f804cbb3_nohash_0.wav',
#   'f8ad3941_nohash_0.wav',
#   'fa446c16_nohash_0.wav',
#   'fb24c826_nohash_0.wav',
#   'fbf3dd31_nohash_1.wav',
#   'fe1916ba_nohash_0.wav',
#   'ffbb695d_nohash_0.wav'],
#  ['012c8314_nohash_0.wav',
#   '0132a06d_nohash_0.wav',
#   '01d22d03_nohash_0.wav',
#   '026290a7_nohash_0.wav',
#   '037c445a_nohash_0.wav',
#   '096456f9_nohash_2.wav',
#   '099d52ad_nohash_0.wav',
#   '0ab3b47d_nohash_0.wav',
#   '0ac15fe9_nohash_0.wav',
#   '0ac15fe9_nohash_1.wav',
#   '0d53e045_nohash_0.wav',
#   '0e17f595_nohash_0.wav',
#   '0f3f64d5_nohash_1.wav',
#   '0fa1e7a9_nohash_0.wav',
#   '10ace7eb_nohash_0.wav',
#   '10f2bb12_nohash_1.wav',
#   '11321027_nohash_1.wav',
#   '11a022ba_nohash_0.wav',
#   '1338a799_nohash_1.wav',
#   '151bfb79_nohash_0.wav',
#   '1625acd8_nohash_0.wav',
#   '171b56dc_nohash_1.wav',
#   '1746d7b6_nohash_0.wav',
#   '17cc40ee_nohash_0.wav',
#   '187af8be_nohash_1.wav',
#   '190821dc_nohash_0.wav',
#   '19785c4e_nohash_0.wav',
#   '1c3f4fac_nohash_1.wav',
#   '1c3f50ad_nohash_1.wav',
#   '1f653d27_nohash_0.wav',
#   '2039b9c1_nohash_1.wav',
#   '283d7a53_nohash_0.wav',
#   '2ce7534c_nohash_0.wav',
#   '2dcb6848_nohash_0.wav',
#   '2f0a410b_nohash_0.wav',
#   '31e686d2_nohash_2.wav',
#   '31e686d2_nohash_3.wav',
#   '34805883_nohash_0.wav',
#   '364c0853_nohash_0.wav',
#   '3777c08e_nohash_1.wav',
#   '3bdf05d3_nohash_1.wav',
#   '3c165869_nohash_0.wav',
#   '3ca784ec_nohash_1.wav',
#   '3d53244b_nohash_0.wav',
#   '3dfd6c23_nohash_1.wav',
#   '3e2ba5f7_nohash_0.wav',
#   '3efa7ec4_nohash_0.wav',
#   '3f2b358d_nohash_0.wav',
#   '3ffa3457_nohash_1.wav',
#   '413997c1_nohash_0.wav',
#   '41dce6f5_nohash_0.wav',
#   '435f9f9e_nohash_0.wav',
#   '437455be_nohash_1.wav',
#   '44f68a83_nohash_0.wav',
#   '46a153d8_nohash_0.wav',
#   '483e2a6f_nohash_0.wav',
#   '4845bb10_nohash_0.wav',
#   '48a9f771_nohash_0.wav',
#   '48a9f771_nohash_1.wav',
#   '493392c6_nohash_0.wav',
#   '49af4432_nohash_0.wav',
#   '4a803e67_nohash_0.wav',
#   '4f256313_nohash_0.wav',
#   '4f2ab70c_nohash_1.wav',
#   '50928b05_nohash_0.wav',
#   '50928b05_nohash_1.wav',
#   '50f55535_nohash_0.wav',
#   '5165cf0a_nohash_0.wav',
#   '5188de0d_nohash_0.wav',
#   '51995cea_nohash_3.wav',
#   '5236848b_nohash_0.wav',
#   '530306f5_nohash_0.wav',
#   '541120c7_nohash_0.wav',
#   '54d9ccb5_nohash_0.wav',
#   '5744b6a7_nohash_1.wav',
#   '5a0bc987_nohash_0.wav',
#   '5b09db89_nohash_0.wav',
#   '617de221_nohash_0.wav',
#   '62581901_nohash_0.wav',
#   '637c702a_nohash_0.wav',
#   '66a412a7_nohash_0.wav',
#   '66cbe2b3_nohash_1.wav',
#   '6940f7f3_nohash_0.wav',
#   '6a203e0e_nohash_0.wav',
#   '6a700f9d_nohash_0.wav',
#   '6e41a77e_nohash_0.wav',
#   '6f7724f5_nohash_0.wav',
#   '6f7724f5_nohash_3.wav',
#   '7195ffa6_nohash_0.wav',
#   '72198b96_nohash_1.wav',
#   '72be9202_nohash_3.wav',
#   '72d75d96_nohash_1.wav',
#   '74551073_nohash_1.wav',
#   '748cb308_nohash_2.wav',
#   '7a5530c9_nohash_1.wav',
#   '7add4c5f_nohash_1.wav',
#   '7c1d8533_nohash_0.wav',
#   '7cb5c0b7_nohash_0.wav',
#   '7e2d5caf_nohash_1.wav',
#   '7fc74fbe_nohash_0.wav',
#   '81dc4a94_nohash_0.wav',
#   '825f450d_nohash_0.wav',
#   '82b99576_nohash_0.wav',
#   '83c9e7e6_nohash_1.wav',
#   '8494fba8_nohash_0.wav',
#   '84999496_nohash_0.wav',
#   '863880b7_nohash_0.wav',
#   '86fa2dcd_nohash_2.wav',
#   '88f8a99c_nohash_0.wav',
#   '8a0457c9_nohash_0.wav',
#   '8dd24423_nohash_0.wav',
#   '8ed25ef8_nohash_0.wav',
#   '91223b83_nohash_1.wav',
#   '96d5276f_nohash_0.wav',
#   '96d5276f_nohash_1.wav',
#   '97101ef3_nohash_0.wav',
#   '9799379a_nohash_0.wav',
#   '98447c43_nohash_0.wav',
#   '99081f4d_nohash_0.wav',
#   '9a8d8d34_nohash_1.wav',
#   '9b027ecf_nohash_0.wav',
#   '9ff2d2f4_nohash_0.wav',
#   'a1a59b72_nohash_0.wav',
#   'a24cf51c_nohash_0.wav',
#   'a24cf51c_nohash_1.wav',
#   'a42a88ff_nohash_1.wav',
#   'a42a88ff_nohash_2.wav',
#   'a4b21cbc_nohash_2.wav',
#   'a518d1cf_nohash_0.wav',
#   'a7545b9f_nohash_0.wav',
#   'a8e25ebb_nohash_0.wav',
#   'a9abc695_nohash_0.wav',
#   'abbfc3b4_nohash_0.wav',
#   'acfd3bc3_nohash_0.wav',
#   'acfd3bc3_nohash_1.wav',
#   'ad89eb1e_nohash_0.wav',
#   'adc216c5_nohash_0.wav',
#   'adebe223_nohash_1.wav',
#   'aff582a1_nohash_0.wav',
#   'b00c4c53_nohash_1.wav',
#   'b01c8f61_nohash_0.wav',
#   'b06c19b0_nohash_0.wav',
#   'b1df80c0_nohash_1.wav',
#   'b21f0fa4_nohash_0.wav',
#   'b2fbe484_nohash_0.wav',
#   'b41a92a3_nohash_0.wav',
#   'b4bef564_nohash_0.wav',
#   'b544d4fd_nohash_1.wav',
#   'b575b5fb_nohash_0.wav',
#   'b737ee80_nohash_2.wav',
#   'b843de62_nohash_1.wav',
#   'b87bdb22_nohash_0.wav',
#   'b9cccd01_nohash_0.wav',
#   'bd11c654_nohash_0.wav',
#   'bd11c654_nohash_1.wav',
#   'c0e8f5a1_nohash_0.wav',
#   'c3538de1_nohash_0.wav',
#   'c4500713_nohash_0.wav',
#   'c4f875a9_nohash_0.wav',
#   'c7aa72e6_nohash_0.wav',
#   'caf9fceb_nohash_0.wav',
#   'cb802c63_nohash_1.wav',
#   'cc6bae0d_nohash_0.wav',
#   'cd7f8c1b_nohash_0.wav',
#   'cd8b1781_nohash_0.wav',
#   'cee22275_nohash_0.wav',
#   'cf68fad2_nohash_0.wav',
#   'd0858dce_nohash_1.wav',
#   'd107dc42_nohash_0.wav',
#   'd107dc42_nohash_2.wav',
#   'd2eae23d_nohash_1.wav',
#   'd312f481_nohash_1.wav',
#   'd4d898d7_nohash_0.wav',
#   'd5356b9a_nohash_0.wav',
#   'd7467392_nohash_1.wav',
#   'd7529c0c_nohash_0.wav',
#   'd7559b2d_nohash_1.wav',
#   'd7a58714_nohash_1.wav',
#   'd85270c1_nohash_0.wav',
#   'da584bc0_nohash_0.wav',
#   'e18b3705_nohash_0.wav',
#   'e48a80ed_nohash_0.wav',
#   'e54a0f16_nohash_0.wav',
#   'e8e960fd_nohash_0.wav',
#   'e96a5020_nohash_0.wav',
#   'e9b61425_nohash_0.wav',
#   'eb0676ec_nohash_0.wav',
#   'eb3d8eb1_nohash_0.wav',
#   'eb609143_nohash_0.wav',
#   'eb6dab4a_nohash_2.wav',
#   'ed0720f1_nohash_0.wav',
#   'f0ae7203_nohash_0.wav',
#   'f1b35ace_nohash_0.wav',
#   'f216055e_nohash_0.wav',
#   'f297e878_nohash_0.wav',
#   'f35eedd7_nohash_0.wav',
#   'f3d06008_nohash_0.wav',
#   'f5c3de1b_nohash_1.wav',
#   'f5e5e8b0_nohash_0.wav',
#   'f5e5e8b0_nohash_1.wav',
#   'f810e799_nohash_0.wav',
#   'f84762e5_nohash_0.wav',
#   'f9273a21_nohash_0.wav',
#   'f9af823e_nohash_0.wav',
#   'fb7cfe0e_nohash_0.wav',
#   'fb7cfe0e_nohash_2.wav',
#   'fbf3dd31_nohash_0.wav',
#   'fc28c8d8_nohash_0.wav',
#   'fda46b78_nohash_0.wav',
#   'ffb86d3c_nohash_1.wav'])

# %%
import wave
import contextlib

# Function to load and display properties of a few audio files using the wave library
def load_and_display_audio_properties_wave(file_paths, category_name, num_samples=5):
    properties = []
    for file in file_paths[:num_samples]:
        file_path = os.path.join(animals_folder_path, category_name, file)
        with contextlib.closing(wave.open(file_path, 'rb')) as f:
            frames = f.getnframes()
            rate = f.getframerate()
            duration = frames / float(rate)
            properties.append({
                "File": file,
                "Sample Rate": rate,
                "Duration (seconds)": duration,
                "Channels": f.getnchannels()
            })
    return properties

# Load and display properties for a few files from each category using wave library
bird_audio_properties_wave = load_and_display_audio_properties_wave(bird_files, 'bird')
cat_audio_properties_wave = load_and_display_audio_properties_wave(cat_files, 'cat')
dog_audio_properties_wave = load_and_display_audio_properties_wave(dog_files, 'dog')

(bird_audio_properties_wave, cat_audio_properties_wave, dog_audio_properties_wave)
# Out:
# ([{'File': '00b01445_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '00f0204f_nohash_1.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '00f0204f_nohash_3.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '01648c51_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '01bcfc0c_nohash_1.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1}],
#  [{'File': '00f0204f_nohash_2.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '03cf93b1_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 0.896,
#    'Channels': 1},
#   {'File': '095847e4_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '096456f9_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '0e5193e6_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1}],
#  [{'File': '012c8314_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '0132a06d_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '01d22d03_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '026290a7_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1},
#   {'File': '037c445a_nohash_0.wav',
#    'Sample Rate': 16000,
#    'Duration (seconds)': 1.0,
#    'Channels': 1}])

# %%
import soundfile as sf

# Function to normalize the duration of audio files
def normalize_audio_duration(file_paths, category_name, target_duration=1.0, sample_rate=16000):
    normalized_files = []
    for file in file_paths:
        file_path = os.path.join(animals_folder_path, category_name, file)
        audio, sr = sf.read(file_path)

        # If the audio is shorter than the target duration, pad it
        if len(audio) < target_duration * sr:
            padding = int((target_duration * sr) - len(audio))
            audio = np.pad(audio, (0, padding), mode='constant')

        # If the audio is longer than the target duration, trim it
        elif len(audio) > target_duration * sr:
            audio = audio[:int(target_duration * sr)]

        # Save the normalized audio to a new file
        normalized_file_path = os.path.join(animals_folder_path, category_name, 'normalized_' + file)
        sf.write(normalized_file_path, audio, sr)
        normalized_files.append(normalized_file_path)

    return normalized_files

# Normalize the duration for a few files from each category
normalized_bird_files = normalize_audio_duration(bird_files[:5], 'bird')
normalized_cat_files = normalize_audio_duration(cat_files[:5], 'cat')
normalized_dog_files = normalize_audio_duration(dog_files[:5], 'dog')

(normalized_bird_files, normalized_cat_files, normalized_dog_files)
# Out:
# (['/content/I/Animals/bird/normalized_00b01445_nohash_0.wav',
#   '/content/I/Animals/bird/normalized_00f0204f_nohash_1.wav',
#   '/content/I/Animals/bird/normalized_00f0204f_nohash_3.wav',
#   '/content/I/Animals/bird/normalized_01648c51_nohash_0.wav',
#   '/content/I/Animals/bird/normalized_01bcfc0c_nohash_1.wav'],
#  ['/content/I/Animals/cat/normalized_00f0204f_nohash_2.wav',
#   '/content/I/Animals/cat/normalized_03cf93b1_nohash_0.wav',
#   '/content/I/Animals/cat/normalized_095847e4_nohash_0.wav',
#   '/content/I/Animals/cat/normalized_096456f9_nohash_0.wav',
#   '/content/I/Animals/cat/normalized_0e5193e6_nohash_0.wav'],
#  ['/content/I/Animals/dog/normalized_012c8314_nohash_0.wav',
#   '/content/I/Animals/dog/normalized_0132a06d_nohash_0.wav',
#   '/content/I/Animals/dog/normalized_01d22d03_nohash_0.wav',
#   '/content/I/Animals/dog/normalized_026290a7_nohash_0.wav',
#   '/content/I/Animals/dog/normalized_037c445a_nohash_0.wav'])

# %%
from scipy.io import wavfile
from scipy.fftpack import dct

# Function to calculate Mel Frequency Cepstral Coefficients (MFCC)
def calculate_mfcc(file_path, num_ceps=13, n_filters=26, n_fft=512, hop_length=160):
    # Load the audio file
    sample_rate, signal = wavfile.read(file_path)

    # Pre-Emphasis
    pre_emphasis = 0.97
    emphasized_signal = np.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])

    # Framing
    frame_size, frame_stride = 0.025, 0.01  # 25ms, 10ms
    frame_length, frame_step = frame_size * sample_rate, frame_stride * sample_rate  # Convert from seconds to samples
    signal_length = len(emphasized_signal)
    frame_length = int(round(frame_length))
    frame_step = int(round(frame_step))
    num_frames = int(np.ceil(float(np.abs(signal_length - frame_length)) / frame_step))  # Make sure that we have at least 1 frame

    pad_signal_length = num_frames * frame_step + frame_length
    z = np.zeros((pad_signal_length - signal_length))
    pad_signal = np.append(emphasized_signal, z)  # Pad signal to make sure that all frames have equal number of samples without truncating any samples from the original signal

    indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
    frames = pad_signal[indices.astype(np.int32, copy=False)]

    # Window
    frames *= np.hamming(frame_length)

    # Fourier-Transform and Power Spectrum
    NFFT = n_fft
    mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitude of the FFT
    pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))  # Power Spectrum

    # Filter Banks
    low_freq_mel = 0
    high_freq_mel = (2595 * np.log10(1 + (sample_rate / 2) / 700))  # Convert Hz to Mel
    mel_points = np.linspace(low_freq_mel, high_freq_mel, n_filters + 2)  # Equally spaced in Mel scale
    hz_points = (700 * (10**(mel_points / 2595) - 1))  # Convert Mel to Hz
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((n_filters, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, n_filters + 1):
        f_m_minus = int(bin[m - 1])   # left
        f_m = int(bin[m])             # center
        f_m_plus = int(bin[m + 1])    # right

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    filter_banks = np.dot(pow_frames, fbank.T)
    filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)  # Numerical Stability
    filter_banks = 20 * np.log10(filter_banks)  # dB

    # MFCCs
    mfcc = dct(filter_banks, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)]  # Keep 2-13

    return mfcc

# Test the function with one audio file from each category
mfcc_bird_sample = calculate_mfcc(normalized_bird_files[0])
mfcc_cat_sample = calculate_mfcc(normalized_cat_files[0])
mfcc_dog_sample = calculate_mfcc(normalized_dog_files[0])

(mfcc_bird_sample.shape, mfcc_cat_sample.shape, mfcc_dog_sample.shape)  # Displaying the shape of the MFCC features for a sample file from each category
# Out:
# ((98, 13), (98, 13), (98, 13))

# %%
# Extract MFCC features for all normalized audio files in each category
def extract_mfcc_for_all_files(file_paths):
    return [calculate_mfcc(file_path) for file_path in file_paths]

# Extracting MFCC features for all normalized files
mfcc_features_bird = extract_mfcc_for_all_files(normalized_bird_files)
mfcc_features_cat = extract_mfcc_for_all_files(normalized_cat_files)
mfcc_features_dog = extract_mfcc_for_all_files(normalized_dog_files)

# Checking the number of files processed in each category
(len(mfcc_features_bird), len(mfcc_features_cat), len(mfcc_features_dog))
# Out:
# (5, 5, 5)

# %%
from sklearn.decomposition import PCA

# Function to flatten MFCC features and apply PCA for dimensionality reduction
def apply_pca_to_mfcc(mfcc_features, n_components=2):
    # Flatten the MFCC features
    flattened_mfcc = np.array([mfcc.flatten() for mfcc in mfcc_features])

    # Apply PCA
    pca = PCA(n_components=n_components)
    pca_features = pca.fit_transform(flattened_mfcc)

    return pca_features

# Apply PCA to the MFCC features of each category
pca_features_bird = apply_pca_to_mfcc(mfcc_features_bird)
pca_features_cat = apply_pca_to_mfcc(mfcc_features_cat)
pca_features_dog = apply_pca_to_mfcc(mfcc_features_dog)

# Shapes of the PCA features for each category
(pca_features_bird.shape, pca_features_cat.shape, pca_features_dog.shape)
# Out:
# ((5, 2), (5, 2), (5, 2))

# %%
from sklearn.cluster import KMeans

# Concatenate all PCA features for clustering
all_pca_features = np.concatenate([pca_features_bird, pca_features_cat, pca_features_dog])

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=0).fit(all_pca_features)

# Retrieve the cluster labels
cluster_labels = kmeans.labels_

cluster_labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 1, 1, 2, 1, 1, 1, 2, 0, 1, 1, 2, 0, 1, 1], dtype=int32)

# %%
import matplotlib.pyplot as plt

# Visualizing the final clustering map
plt.figure(figsize=(10, 6))
plt.scatter(all_pca_features[:, 0], all_pca_features[:, 1], c=cluster_labels, cmap='viridis', marker='o')

# Annotating the points
for i, txt in enumerate(cluster_labels):
    plt.annotate(txt, (all_pca_features[i, 0], all_pca_features[i, 1]))

plt.title('Clustering of Audio Files based on PCA-Reduced MFCC Features')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster Label')
plt.grid(True)
plt.show()
